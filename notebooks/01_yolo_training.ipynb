# %%
import ultralytics
import cv2
import numpy as np
import os
import random
from roboflow import Roboflow
from ultralytics import YOLO

# %%
rf = Roboflow(api_key="RxvZ7b2FpmXHfTDOdE69")
project = rf.workspace("intita2025").project("meters-water")
dataset = project.version(1).download("yolov8-obb")

# %%
model = YOLO('yolov8n-obb.pt')

results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=30,          
    imgsz=640,           
    batch=16,
    plots=True           
)
